# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def forceLandscape(image):
    if image.shape[0] > image.shape[1]:
        return np.rot90(image)

# %%
img = mpimg.imread('sample_images/iss010e07356.jpg')
plt.imshow(img)
plt.show()

# %%
print(img.shape)
# Out:
# (3032, 2008, 3)
