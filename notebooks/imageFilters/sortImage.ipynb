# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import scipy
from scipy import misc

# %%
def resizeImage(image, x,y):
    return scipy.misc.imresize(image,(x,y), interp='nearest')

# %%
img1 = mpimg.imread('../sample_images/_31R2736.jpg')
img1 = resizeImage(img1, 300,500)
plt.imshow(img1)
plt.show()
print(img1.shape)
print('feature size: ' + str(img1.shape[0]*img1.shape[1] * img1.shape[2]))
# Out:
# (300, 500, 3)
# feature size: 450000

# %%
def sortImage(image, axis=1):
    return np.sort(image,axis)

# %%
sortImg = sortImage(img1,axis=0)
plt.imshow(sortImg)
plt.show()
print(sortImg.shape)
print('feature size: ' + str(sortImg.shape[0]*sortImg.shape[1] * sortImg.shape[2]))
# Out:
# (300, 500, 3)
# feature size: 450000

# %%
sortImg2 = sortImage(img1, axis=1)
plt.imshow(sortImg2)
plt.show()
print(sortImg2.shape)
print('feature size: ' + str(sortImg2.shape[0]*sortImg2.shape[1] * sortImg2.shape[2]))
# Out:
# (300, 500, 3)
# feature size: 450000

# %%
sortImg3 = sortImage(sortImage(img1, axis=0),axis=1)
plt.imshow(sortImg3)
plt.show()
print(sortImg3.shape)
print('feature size: ' + str(sortImg3.shape[0]*sortImg3.shape[1] * sortImg3.shape[2]))
# Out:
# (300, 500, 3)
# feature size: 450000

# %%
sortImg4 = sortImage(sortImage(img1, axis=1),axis=0)
plt.imshow(sortImg4)
plt.show()
print(sortImg4.shape)
print('feature size: ' + str(sortImg4.shape[0]*sortImg4.shape[1] * sortImg4.shape[2]))
# Out:
# (300, 500, 3)
# feature size: 450000

# %% [markdown]
# Why this might be useful, Star photos, since there mostly dark we can sort them

# %%
img2 = mpimg.imread('../sample_images/iss041e006925.jpg')
img2 = resizeImage(img2, 300,500)
plt.imshow(img2)
plt.show()
print(img2.shape)
print('feature size: ' + str(img2.shape[0]*img2.shape[1] * img2.shape[2]))
# Out:
# (300, 500, 3)
# feature size: 450000

# %%
sortImg5 =sortImage(img2, axis=0)
plt.imshow(sortImg5)
plt.show()
print(sortImg5.shape)
print('feature size: ' + str(sortImg5.shape[0]*sortImg5.shape[1] * sortImg5.shape[2]))
# Out:
# (300, 500, 3)
# feature size: 450000
